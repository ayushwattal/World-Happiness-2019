# %% [markdown]
# # EDA: Visualization with matplotlib and seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # 1. Load the dataset into a Pandas dataframe

# %%
# Reading Dataset
dataSet = pd.read_csv("../input/world-happiness/2019.csv")

# %%
# Rounding Upto 2 Decimal Point
pd.set_option('precision',2)

# %% [markdown]
# # 2.  Display the data as a table with suitable column headings

# %%
#Display first 20 rows
dataSet.head(20)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland   7.77            1.34            1.59
# 1              2           Denmark   7.60            1.38            1.57
# 2              3            Norway   7.55            1.49            1.58
# 3              4           Iceland   7.49            1.38            1.62
# 4              5       Netherlands   7.49            1.40            1.52
# 5              6       Switzerland   7.48            1.45            1.53
# 6              7            Sweden   7.34            1.39            1.49
# 7              8       New Zealand   7.31            1.30            1.56
# 8              9            Canada   7.28            1.36            1.50
# 9             10           Austria   7.25            1.38            1.48
# 10            11         Australia   7.23            1.37            1.55
# 11            12        Costa Rica   7.17            1.03            1.44
# ...

# %%
#Display last 20 rows
dataSet.tail(20)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 136           137                     Egypt   4.17            0.91
# 137           138                    Zambia   4.11            0.58
# 138           139                      Togo   4.08            0.28
# 139           140                     India   4.01            0.76
# 140           141                   Liberia   3.98            0.07
# 141           142                   Comoros   3.97            0.27
# 142           143                Madagascar   3.93            0.27
# 143           144                   Lesotho   3.80            0.49
# 144           145                   Burundi   3.77            0.05
# 145           146                  Zimbabwe   3.66            0.37
# 146           147                     Haiti   3.60            0.32
# 147           148                  Botswana   3.49            1.04
# 148           149                     Syria   3.46            0.62
# ...

# %% [markdown]
# # 3. Display some simple statistics of the data

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# Display simple Stats for Coulmn'Score','Social support', 'Healthy life expectancy'

# %%
#Display simple Stats for Coulmn'Score','Social support', 'Healthy life expectancy'

dataSet[['Score','Social support', 'Healthy life expectancy']].describe()
# Out:
#         Score  Social support  Healthy life expectancy
# count  156.00          156.00                   156.00
# mean     5.41            1.21                     0.73
# std      1.11            0.30                     0.24
# min      2.85            0.00                     0.00
# 25%      4.54            1.06                     0.55
# 50%      5.38            1.27                     0.79
# 75%      6.18            1.45                     0.88
# max      7.77            1.62                     1.14

# %%
#Changing the names of columns header
dataSet.columns = ['Rank','Country','Score','GdpPerCapita' ,'SocialSupport','Healthy life expectancy','Freedom to make life choices' ,'Generosity', 'Perceptions of corruption']

# %% [markdown]
# # 4. Create one or more histograms

# %%
# Creating a bar graph for top 5 ranking countries with respect to Genoriosity

plt.bar(dataSet.head(5)['Country'],dataSet.head(5)['Generosity'])
plt.ylabel("Genoriosity", fontsize=15,color="Green")
plt.xlabel("Country", fontsize=15,color="Blue")
# Out:
# Text(0.5, 0, 'Country')

# %%
# Creating a bar graph for top 5 ranking countries with respect to Social Support

plt.bar(dataSet.head(5)['Country'],dataSet.head(5)['SocialSupport'])
plt.ylabel("SocialSupport", fontsize=15,color="Green")
plt.xlabel("Country", fontsize=15,color="Blue")
# Out:
# Text(0.5, 0, 'Country')

# %%
#Plot a line graph for Top 20 Entries ,comparing GDP per Capita with Health Life Expectancy

sns.lineplot(data = dataSet.head(20), x = "GdpPerCapita", y = "Healthy life expectancy")
# Out:
# <AxesSubplot:xlabel='GdpPerCapita', ylabel='Healthy life expectancy'>

# %%
sns.pairplot(dataSet, vars = ['Rank','Score','GdpPerCapita' ,'SocialSupport','Healthy life expectancy'], kind = 'kde',corner = True)

# %%
#Plot a line graph for Top 20 Entries ,comparing Social support with Health Life Expectancy

sns.lineplot(data = dataSet.head(20), x = "SocialSupport", y = "Healthy life expectancy")
# Out:
# <AxesSubplot:xlabel='SocialSupport', ylabel='Healthy life expectancy'>
